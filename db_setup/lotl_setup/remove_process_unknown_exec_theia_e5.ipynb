# %%
import os
import sys
from pathlib import Path


nb_dir = Path.cwd()
        

target = (nb_dir / '..' / '..').resolve()
os.chdir(target)

# %%
from grasp.graph.graph_storage import GraphStorage
from grasp.graph.graph_storage import load_graph_storage

gs_path = "data/theia_e5/graph_storage/theia_e5_default_experiment_dataset-theia_e5_context_size-120_step_size-120_graph_storage.pt"
gs: GraphStorage = load_graph_storage(gs_path)


print(gs)
known_executables = gs.train_subject_cmds
print(len(known_executables))
print(len(known_executables))
# Out:
# <grasp.graph.graph_storage.GraphStorage object at 0x7589b279b7d0>
# 848788
# 848788

# %%
gs.train_subject_cmds
# Out:
# ['/sbin/modprobe',
#  '/sbin/modprobe',
#  '/sbin/modprobe',
#  '/sbin/modprobe',
#  '/sbin/modprobe',
#  '/sbin/modprobe',
#  '/usr/bin/python2.7',
#  '/sbin/modprobe',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/sshd',
#  '/usr/sbin/sshd',
#  '/usr/sbin/sshd',
#  '/bin/bash',
#  '/usr/bin/whoopsie',
#  '/usr/sbin/unity-greeter',
#  '/usr/sbin/avahi-daemon',
#  '/bin/dash',
#  '/usr/bin/xscreensaver',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/usr/bin/prometheus-node-exporter',
#  '/usr/bin/prometheus-node-exporter',
#  '/sbin/modprobe',
#  '/usr/sbin/ntpd',
#  '/bin/bash',
#  '/bin/dbus-daemon',
#  '/usr/lib/udisks/udisks-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/bin/xfce4-power-manager',
#  '/usr/sbin/NetworkManager',
#  '/usr/lib/policykit-1/polkitd',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/zeitgeist-daemon',
#  '/usr/bin/zeitgeist-daemon',
#  '/usr/bin/prometheus-node-exporter',
#  '/sbin/modprobe',
#  '/sbin/modprobe',
#  '/usr/sbin/sshd',
#  '/usr/sbin/sshd',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/sshd',
#  '/bin/dash',
#  '/bin/run-parts',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/run-parts',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/run-parts',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/python2.7',
#  '/bin/dash',
#  '/usr/bin/python2.7',
#  '/bin/dash',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/bin/run-parts',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/apt-config',
#  '/bin/dash',
#  '/usr/bin/apt-config',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/apt-config',
#  '/bin/dash',
#  '/usr/bin/apt-config',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/run-parts',
#  '/bin/dash',
#  '/bin/run-parts',
#  '/bin/dash',
#  '/usr/bin/apt-config',
#  '/bin/dash',
#  '/usr/bin/apt-config',
#  '/bin/dash',
#  '/usr/bin/apt-config',
#  '/bin/dash',
#  '/usr/bin/apt-config',
#  '/bin/dash',
#  '/usr/bin/apt-config',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/run-parts',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/run-parts',
#  '/bin/run-parts',
#  '/usr/sbin/sshd',
#  '/usr/sbin/sshd',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/bin/dash',
#  '/bin/dash',
#  '/sbin/modprobe',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/bin/dash',
#  '/bin/dash',
#  '/sbin/modprobe',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/su',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/xscreensaver',
#  '/usr/bin/xscreensaver',
#  '/usr/bin/xscreensaver',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/su',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/xfce4-volumed',
#  '/usr/lib/zeitgeist/zeitgeist-fts',
#  '/bin/dash',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/usr/lib/zeitgeist/zeitgeist-fts',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/lib/gvfs/gvfs-gdu-volume-monitor',
#  '/usr/lib/at-spi2-core/at-spi-bus-launcher',
#  '/usr/sbin/console-kit-daemon',
#  '/sbin/udevd',
#  '/sbin/udevd',
#  '/sbin/upstart-udev-bridge',
#  '/usr/sbin/console-kit-daemon',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/su',
#  '/bin/fusermount',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/Xvnc4',
#  '/usr/bin/perl',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/Xvnc4',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/dbus-launch',
#  '/usr/bin/dbus-launch',
#  '/usr/bin/dbus-launch',
#  '/bin/dbus-daemon',
#  '/bin/dash',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/ssh-agent',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/xscreensaver',
#  '/bin/dash',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/bin/dash',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfwm4',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfsettingsd',
#  '/usr/bin/xfwm4',
#  '/usr/bin/xfsettingsd',
#  '/usr/bin/xfwm4',
#  '/usr/bin/xfsettingsd',
#  '/usr/bin/Thunar',
#  '/usr/bin/Thunar',
#  '/usr/bin/Thunar',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/lib/gvfs/gvfsd',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/usr/bin/xfdesktop',
#  '/bin/fusermount',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/usr/bin/xfdesktop',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/usr/bin/xfdesktop',
#  '/usr/bin/xfce4-session',
#  '/usr/lib/policykit-1-gnome/polkit-gnome-authentication-agent-1',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/nm-applet',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/lib/policykit-1-gnome/polkit-gnome-authentication-agent-1',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/bin/dash',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/lib/policykit-1-gnome/polkit-gnome-authentication-agent-1',
#  '/usr/bin/xfce4-session',
#  '/bin/dash',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/python2.7',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/update-notifier',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/zeitgeist-daemon',
#  '/usr/bin/xfce4-session',
#  '/bin/dash',
#  '/usr/bin/bluetooth-applet',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/xfce4-session',
#  '/bin/dash',
#  '/usr/bin/xfce4-session',
#  '/bin/dash',
#  '/usr/bin/zeitgeist-daemon',
#  '/usr/bin/zeitgeist-daemon',
#  '/usr/bin/zeitgeist-daemon',
#  '/bin/dbus-daemon',
#  '/bin/dash',
#  '/usr/bin/zeitgeist-daemon',
#  '/bin/dbus-daemon',
#  '/usr/bin/zeitgeist-daemon',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/nm-applet',
#  '/usr/lib/zeitgeist/zeitgeist-fts',
#  '/usr/bin/xfce4-power-manager',
#  '/usr/lib/zeitgeist/zeitgeist-fts',
#  '/usr/bin/nm-applet',
#  '/usr/bin/xfce4-volumed',
#  '/usr/bin/xfce4-power-manager',
#  '/usr/bin/xfce4-power-manager',
#  '/usr/bin/xfce4-volumed',
#  '/bin/dash',
#  '/usr/bin/xfce4-volumed',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/update-notifier',
#  '/usr/bin/bluetooth-applet',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/xfce4-volumed',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/update-notifier',
#  '/usr/bin/bluetooth-applet',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/xfce4-volumed',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/bin/xfce4-volumed',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/pulseaudio',
#  '/usr/lib/rtkit/rtkit-daemon',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/lib/pulseaudio/pulse/gconf-helper',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/lib/gvfs/gvfs-afc-volume-monitor',
#  '/bin/dbus-daemon',
#  '/sbin/modprobe',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/bin/bluetooth-applet',
#  '/usr/bin/python2.7',
#  '/usr/lib/x86_64-linux-gnu/tumbler-1/tumblerd',
#  '/usr/lib/x86_64-linux-gnu/tumbler-1/tumblerd',
#  '/usr/bin/python2.7',
#  '/usr/bin/update-notifier',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/xfce4-volumed',
#  '/usr/bin/python2.7',
#  '/usr/bin/xfdesktop',
#  '/usr/bin/python2.7',
#  '/usr/bin/xfce4-volumed',
#  '/usr/lib/gvfs/gvfsd',
#  '/usr/lib/gvfs/gvfsd',
#  '/usr/bin/nm-applet',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/lib/xfce4/notifyd/xfce4-notifyd',
#  '/usr/lib/xfce4/notifyd/xfce4-notifyd',
#  '/bin/dash',
#  '/usr/bin/update-notifier',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/bin/dash',
#  '/usr/bin/python2.7',
#  '/bin/dash',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/lib/at-spi2-core/at-spi-bus-launcher',
#  '/usr/lib/at-spi2-core/at-spi-bus-launcher',
#  '/usr/lib/at-spi2-core/at-spi-bus-launcher',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/sbin/modprobe',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/sbin/init',
#  '/bin/dash',
#  '/usr/sbin/sshd',
#  '/bin/bash',
#  '/sbin/modprobe',
#  '/sbin/modprobe',
#  '/sbin/modprobe',
#  '/sbin/modprobe',
#  '/usr/bin/sudo',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/sbin/modprobe',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/su',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/fusermount',
#  '/bin/dash',
#  '/bin/su',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/usr/bin/perl',
#  '/bin/dash',
#  '/usr/bin/perl',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/Xvnc4',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/dbus-launch',
#  '/usr/bin/dbus-launch',
#  '/usr/bin/dbus-launch',
#  '/bin/dbus-daemon',
#  '/bin/dash',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/ssh-agent',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/bin/dash',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfsettingsd',
#  '/usr/bin/xfwm4',
#  '/usr/bin/xfsettingsd',
#  '/usr/bin/xfsettingsd',
#  '/usr/bin/xfwm4',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/Thunar',
#  '/usr/bin/Thunar',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/lib/gvfs/gvfsd',
#  '/usr/lib/gvfs/gvfsd',
#  '/usr/bin/xfce4-session',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/bin/fusermount',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/usr/bin/xfdesktop',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/usr/bin/xfdesktop',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/lib/policykit-1-gnome/polkit-gnome-authentication-agent-1',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/xfce4-session',
#  '/bin/dash',
#  '/usr/bin/xfce4-session',
#  '/usr/lib/policykit-1-gnome/polkit-gnome-authentication-agent-1',
#  '/usr/bin/xfce4-session',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/bin/zeitgeist-daemon',
#  '/bin/dash',
#  '/usr/bin/xfce4-session',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/zeitgeist-daemon',
#  '/usr/bin/zeitgeist-daemon',
#  '/usr/bin/zeitgeist-daemon',
#  '/usr/bin/xfce4-session',
#  '/bin/dash',
#  '/bin/dbus-daemon',
#  '/usr/bin/zeitgeist-daemon',
#  '/bin/dbus-daemon',
#  '/usr/bin/zeitgeist-daemon',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/bin/dash',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/bin/nm-applet',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-session',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-power-manager',
#  '/usr/lib/zeitgeist/zeitgeist-fts',
#  '/bin/dash',
#  '/usr/lib/zeitgeist/zeitgeist-fts',
#  '/usr/bin/nm-applet',
#  '/usr/bin/xfce4-power-manager',
#  '/usr/bin/update-notifier',
#  '/usr/bin/xfce4-volumed',
#  '/usr/bin/xfce4-volumed',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/xfce4-volumed',
#  '/usr/bin/bluetooth-applet',
#  '/usr/bin/update-notifier',
#  '/bin/dash',
#  '/usr/bin/bluetooth-applet',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/xfce4-volumed',
#  '/bin/dash',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/bin/xfce4-volumed',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/pulseaudio',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/bin/pulseaudio',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/lib/gvfs/gvfs-afc-volume-monitor',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/lib/x86_64-linux-gnu/tumbler-1/tumblerd',
#  '/usr/lib/x86_64-linux-gnu/tumbler-1/tumblerd',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/xfce4-volumed',
#  '/usr/bin/bluetooth-applet',
#  '/usr/bin/xfdesktop',
#  '/usr/lib/gvfs/gvfsd',
#  '/usr/lib/gvfs/gvfsd',
#  '/usr/bin/xfce4-volumed',
#  '/usr/bin/python2.7',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/lib/xfce4/notifyd/xfce4-notifyd',
#  '/usr/lib/xfce4/notifyd/xfce4-notifyd',
#  '/usr/bin/update-notifier',
#  '/usr/bin/nm-applet',
#  '/bin/dash',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/bin/update-notifier',
#  '/usr/bin/python2.7',
#  '/bin/dash',
#  '/usr/bin/python2.7',
#  '/bin/dash',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/lib/at-spi2-core/at-spi-bus-launcher',
#  '/usr/lib/at-spi2-core/at-spi-bus-launcher',
#  '/usr/lib/at-spi2-core/at-spi-bus-launcher',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/bin/python2.7',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/sbin/init',
#  '/bin/dash',
#  '/sbin/init',
#  '/usr/bin/python2.7',
#  '/sbin/modprobe',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/usr/bin/python2.7',
#  '/sbin/modprobe',
#  '/usr/bin/update-notifier',
#  '/usr/bin/update-notifier',
#  '/usr/bin/update-notifier',
#  '/bin/bash',
#  '/bin/bash',
#  '/sbin/modprobe',
#  '/bin/bash',
#  '/usr/sbin/sshd',
#  '/usr/sbin/sshd',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/sshd',
#  '/bin/dash',
#  '/bin/run-parts',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/run-parts',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/run-parts',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/python2.7',
#  '/bin/dash',
#  '/usr/bin/python2.7',
#  '/bin/dash',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/bin/run-parts',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/bin/apt-config',
#  '/bin/dash',
#  '/usr/bin/apt-config',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  '/bin/dash',
#  ...]

# %%
gs.train_subject_cmd_to_id
# Out:
# {'/bin/bash': 0,
#  '/bin/dash': 1,
#  '/bin/dbus-daemon': 2,
#  '/bin/fusermount': 3,
#  '/bin/run-parts': 4,
#  '/bin/su': 5,
#  '/sbin/dhclient': 6,
#  '/sbin/init': 7,
#  '/sbin/modprobe': 8,
#  '/sbin/udevd': 9,
#  '/sbin/upstart-udev-bridge': 10,
#  '/usr/bin/Thunar': 11,
#  '/usr/bin/Xorg': 12,
#  '/usr/bin/Xvnc4': 13,
#  '/usr/bin/apt-config': 14,
#  '/usr/bin/apt-get': 15,
#  '/usr/bin/bluetooth-applet': 16,
#  '/usr/bin/dbus-launch': 17,
#  '/usr/bin/evince': 18,
#  '/usr/bin/exo-open': 19,
#  '/usr/bin/find': 20,
#  '/usr/bin/gcalctool': 21,
#  '/usr/bin/gdbus': 22,
#  '/usr/bin/gedit': 23,
#  '/usr/bin/gnome-terminal': 24,
#  '/usr/bin/nm-applet': 25,
#  '/usr/bin/perl': 26,
#  '/usr/bin/prometheus-node-exporter': 27,
#  '/usr/bin/pulseaudio': 28,
#  '/usr/bin/python2.7': 29,
#  '/usr/bin/scp': 30,
#  '/usr/bin/ssh-agent': 31,
#  '/usr/bin/sudo': 32,
#  '/usr/bin/update-notifier': 33,
#  '/usr/bin/whoopsie': 34,
#  '/usr/bin/xargs': 35,
#  '/usr/bin/xfce4-power-manager': 36,
#  '/usr/bin/xfce4-session': 37,
#  '/usr/bin/xfce4-settings-manager': 38,
#  '/usr/bin/xfce4-volumed': 39,
#  '/usr/bin/xfdesktop': 40,
#  '/usr/bin/xfrun4': 41,
#  '/usr/bin/xfsettingsd': 42,
#  '/usr/bin/xfwm4': 43,
#  '/usr/bin/xinit': 44,
#  '/usr/bin/xscreensaver': 45,
#  '/usr/bin/zeitgeist-daemon': 46,
#  '/usr/bin/zeitgeist-datahub': 47,
#  '/usr/games/gnomine': 48,
#  '/usr/games/mahjongg': 49,
#  '/usr/games/sol': 50,
#  '/usr/lib/apt/methods/rsh': 51,
#  '/usr/lib/at-spi2-core/at-spi-bus-launcher': 52,
#  '/usr/lib/at-spi2-core/at-spi2-registryd': 53,
#  '/usr/lib/dconf/dconf-service': 54,
#  '/usr/lib/firefox/crashreporter': 55,
#  '/usr/lib/firefox/firefox': 56,
#  '/usr/lib/gnome-settings-daemon/gnome-settings-daemon': 57,
#  '/usr/lib/gvfs/gvfs-afc-volume-monitor': 58,
#  '/usr/lib/gvfs/gvfs-fuse-daemon': 59,
#  '/usr/lib/gvfs/gvfs-gdu-volume-monitor': 60,
#  '/usr/lib/gvfs/gvfsd': 61,
#  '/usr/lib/gvfs/gvfsd-network': 62,
#  '/usr/lib/gvfs/gvfsd-smb-browse': 63,
#  '/usr/lib/indicator-application/indicator-application-service': 64,
#  '/usr/lib/indicator-datetime/indicator-datetime-service': 65,
#  '/usr/lib/indicator-sound/indicator-sound-service': 66,
#  '/usr/lib/policykit-1-gnome/polkit-gnome-authentication-agent-1': 67,
#  '/usr/lib/policykit-1/polkitd': 68,
#  '/usr/lib/pulseaudio/pulse/gconf-helper': 69,
#  '/usr/lib/rtkit/rtkit-daemon': 70,
#  '/usr/lib/thunderbird/crashreporter': 71,
#  '/usr/lib/thunderbird/thunderbird': 72,
#  '/usr/lib/ubuntu-geoip/ubuntu-geoip-provider': 73,
#  '/usr/lib/udisks/udisks-daemon': 74,
#  '/usr/lib/x86_64-linux-gnu/gconf/gconfd-2': 75,
#  '/usr/lib/x86_64-linux-gnu/tumbler-1/tumblerd': 76,
#  '/usr/lib/x86_64-linux-gnu/xfce4/exo-1/exo-helper-1': 77,
#  '/usr/lib/x86_64-linux-gnu/xfce4/xfwm4/helper-dialog': 78,
#  '/usr/lib/xfce4/notifyd/xfce4-notifyd': 79,
#  '/usr/lib/zeitgeist/zeitgeist-fts': 80,
#  '/usr/local/lib/firefox-54.0.1/crashreporter': 81,
#  '/usr/local/lib/firefox-54.0.1/firefox': 82,
#  '/usr/sbin/NetworkManager': 83,
#  '/usr/sbin/anacron': 84,
#  '/usr/sbin/avahi-daemon': 85,
#  '/usr/sbin/bluetoothd': 86,
#  '/usr/sbin/console-kit-daemon': 87,
#  '/usr/sbin/cron': 88,
#  '/usr/sbin/cupsd': 89,
#  '/usr/sbin/lightdm': 90,
#  '/usr/sbin/logrotate': 91,
#  '/usr/sbin/ntpd': 92,
#  '/usr/sbin/rpc.mountd': 93,
#  '/usr/sbin/sshd': 94,
#  '/usr/sbin/unity-greeter': 95}

# %%
len(set(known_executables))
# Out:
# 96

# %%
known_executables_set = set(known_executables)
known_executables_list = sorted(known_executables_set)
print(len(known_executables_list))
known_executables_list
# Out:
# 96
# ['/bin/bash',
#  '/bin/dash',
#  '/bin/dbus-daemon',
#  '/bin/fusermount',
#  '/bin/run-parts',
#  '/bin/su',
#  '/sbin/dhclient',
#  '/sbin/init',
#  '/sbin/modprobe',
#  '/sbin/udevd',
#  '/sbin/upstart-udev-bridge',
#  '/usr/bin/Thunar',
#  '/usr/bin/Xorg',
#  '/usr/bin/Xvnc4',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-get',
#  '/usr/bin/bluetooth-applet',
#  '/usr/bin/dbus-launch',
#  '/usr/bin/evince',
#  '/usr/bin/exo-open',
#  '/usr/bin/find',
#  '/usr/bin/gcalctool',
#  '/usr/bin/gdbus',
#  '/usr/bin/gedit',
#  '/usr/bin/gnome-terminal',
#  '/usr/bin/nm-applet',
#  '/usr/bin/perl',
#  '/usr/bin/prometheus-node-exporter',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/python2.7',
#  '/usr/bin/scp',
#  '/usr/bin/ssh-agent',
#  '/usr/bin/sudo',
#  '/usr/bin/update-notifier',
#  '/usr/bin/whoopsie',
#  '/usr/bin/xargs',
#  '/usr/bin/xfce4-power-manager',
#  '/usr/bin/xfce4-session',
#  '/usr/bin/xfce4-settings-manager',
#  '/usr/bin/xfce4-volumed',
#  '/usr/bin/xfdesktop',
#  '/usr/bin/xfrun4',
#  '/usr/bin/xfsettingsd',
#  '/usr/bin/xfwm4',
#  '/usr/bin/xinit',
#  '/usr/bin/xscreensaver',
#  '/usr/bin/zeitgeist-daemon',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/games/gnomine',
#  '/usr/games/mahjongg',
#  '/usr/games/sol',
#  '/usr/lib/apt/methods/rsh',
#  '/usr/lib/at-spi2-core/at-spi-bus-launcher',
#  '/usr/lib/at-spi2-core/at-spi2-registryd',
#  '/usr/lib/dconf/dconf-service',
#  '/usr/lib/firefox/crashreporter',
#  '/usr/lib/firefox/firefox',
#  '/usr/lib/gnome-settings-daemon/gnome-settings-daemon',
#  '/usr/lib/gvfs/gvfs-afc-volume-monitor',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/usr/lib/gvfs/gvfs-gdu-volume-monitor',
#  '/usr/lib/gvfs/gvfsd',
#  '/usr/lib/gvfs/gvfsd-network',
#  '/usr/lib/gvfs/gvfsd-smb-browse',
#  '/usr/lib/indicator-application/indicator-application-service',
#  '/usr/lib/indicator-datetime/indicator-datetime-service',
#  '/usr/lib/indicator-sound/indicator-sound-service',
#  '/usr/lib/policykit-1-gnome/polkit-gnome-authentication-agent-1',
#  '/usr/lib/policykit-1/polkitd',
#  '/usr/lib/pulseaudio/pulse/gconf-helper',
#  '/usr/lib/rtkit/rtkit-daemon',
#  '/usr/lib/thunderbird/crashreporter',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/ubuntu-geoip/ubuntu-geoip-provider',
#  '/usr/lib/udisks/udisks-daemon',
#  '/usr/lib/x86_64-linux-gnu/gconf/gconfd-2',
#  '/usr/lib/x86_64-linux-gnu/tumbler-1/tumblerd',
#  '/usr/lib/x86_64-linux-gnu/xfce4/exo-1/exo-helper-1',
#  '/usr/lib/x86_64-linux-gnu/xfce4/xfwm4/helper-dialog',
#  '/usr/lib/xfce4/notifyd/xfce4-notifyd',
#  '/usr/lib/zeitgeist/zeitgeist-fts',
#  '/usr/local/lib/firefox-54.0.1/crashreporter',
#  '/usr/local/lib/firefox-54.0.1/firefox',
#  '/usr/sbin/NetworkManager',
#  '/usr/sbin/anacron',
#  '/usr/sbin/avahi-daemon',
#  '/usr/sbin/bluetoothd',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/cron',
#  '/usr/sbin/cupsd',
#  '/usr/sbin/lightdm',
#  '/usr/sbin/logrotate',
#  '/usr/sbin/ntpd',
#  '/usr/sbin/rpc.mountd',
#  '/usr/sbin/sshd',
#  '/usr/sbin/unity-greeter']

# %%
import time
from urllib.parse import urlparse, unquote

import psycopg2
from psycopg2 import sql

from grasp import config
from grasp.schema import DatasetName

user = "postgres"
password = "lolroflomg"
host = config.DB_HOST
port = 9889

base_url = f"postgresql://{user}:{password}@{host}:{port}"
connection_real_data = f"{base_url}/{DatasetName.THEIA_E5.value}"

# Known executable commands from training graph storage
known_executables_set = set(known_executables)
known_executables_list = sorted(known_executables_set)

new_table_name = "subject_node_table"
backup_table_name = f"{new_table_name}_backup"

# Parse connection URL once
parsed = urlparse(connection_real_data)
dbname = parsed.path.lstrip('/') if parsed.path else None
db_user = unquote(parsed.username) if parsed.username else None
db_password = unquote(parsed.password) if parsed.password else None
db_host = parsed.hostname
db_port = parsed.port

t0 = time.perf_counter()
conn = psycopg2.connect(
    dbname=dbname,
    user=db_user,
    password=db_password,
    host=db_host,
    port=db_port,
    application_name="remove_process_unknown_exec_fast",
)

try:
    with conn:
        with conn.cursor() as cur:
            # Fast path: keep one immutable backup, recreate filtered table from it.
            # If backup already exists, reuse it. If not, rename original once.
            cur.execute("SELECT to_regclass(%s)", (new_table_name,))
            has_main = cur.fetchone()[0] is not None
            cur.execute("SELECT to_regclass(%s)", (backup_table_name,))
            has_backup = cur.fetchone()[0] is not None

            if not has_main and not has_backup:
                raise RuntimeError(
                    f"Neither '{new_table_name}' nor '{backup_table_name}' exists."
                )

            if has_main and not has_backup:
                t_rename = time.perf_counter()
                cur.execute(
                    sql.SQL("ALTER TABLE {} RENAME TO {}").format(
                        sql.Identifier(new_table_name),
                        sql.Identifier(backup_table_name),
                    )
                )
                print(
                    f"Renamed original table to backup in "
                    f"{time.perf_counter() - t_rename:.3f}s"
                )
            elif has_main and has_backup:
                # Keep existing backup as source of truth; refresh working table below.
                print(
                    f"Both '{new_table_name}' and '{backup_table_name}' exist; "
                    "keeping backup and refreshing working table."
                )

            source_table = backup_table_name if has_backup or has_main else new_table_name

            # Remember node_uuids that will be removed (unknown execs + NULL cmd)
            t_collect = time.perf_counter()
            cur.execute(
                sql.SQL(
                    """
                    SELECT hash_id
                    FROM {}
                    WHERE path IS NULL OR NOT (path = ANY(%s))
                    """
                ).format(sql.Identifier(source_table)),
                (known_executables_list,),
            )
            deleted_node_hash_ids = [row[0] for row in cur.fetchall()]
            print(
                f"Collected {len(deleted_node_hash_ids)} deleted node_hash_ids in "
                f"{time.perf_counter() - t_collect:.3f}s"
            )

            t_rebuild = time.perf_counter()
            cur.execute(
                sql.SQL("DROP TABLE IF EXISTS {}").format(
                    sql.Identifier(new_table_name)
                )
            )
            cur.execute(
                sql.SQL("CREATE TABLE {} (LIKE {} INCLUDING ALL)").format(
                    sql.Identifier(new_table_name),
                    sql.Identifier(source_table),
                )
            )
            cur.execute(
                sql.SQL(
                    "INSERT INTO {} SELECT * FROM {} WHERE path = ANY(%s)"
                ).format(
                    sql.Identifier(new_table_name),
                    sql.Identifier(source_table),
                ),
                (known_executables_list,),
            )

            inserted_rows = cur.rowcount
            print(
                f"Rebuilt filtered '{new_table_name}' with {inserted_rows} rows in "
                f"{time.perf_counter() - t_rebuild:.3f}s"
            )

            # Useful sanity numbers
            cur.execute(
                sql.SQL("SELECT COUNT(*) FROM {}").format(
                    sql.Identifier(source_table) 
                )
            )
            source_count = cur.fetchone()[0]
            print(f"Source rows: {source_count}")
            print(f"Deleted rows: {source_count - inserted_rows}")

finally:
    conn.close()

print(f"Total elapsed: {time.perf_counter() - t0:.3f}s")
# Out:
# Renamed original table to backup in 0.003s
# Collected 29029 deleted node_hash_ids in 0.710s
# Rebuilt filtered 'subject_node_table' with 1235411 rows in 9.696s
# Source rows: 1264440
# Deleted rows: 29029
# Total elapsed: 10.479s

# %%
deleted_node_hash_ids
# Out:
# ['5479dc389d8899e8c52d77344ddbbcdde1569cdf60111f358bd4290f07bad333',
#  '50c6db8602bee42051675da079e4f495afee35aeb08a143fb06645db3f8d0bb3',
#  '87b776f8019a8b23b8f87aa02e0e6072e817cd5df323de7d4b4120980776bee1',
#  '27ab3c95649095e3bb322a84a29f59028695d627e460b5c23c74de5948a2189c',
#  '2a5f08b1a5371019ac07b607ef60c8373523c59893df38331af7899e2f2659bb',
#  '1d60f99979a5f5a496c97663eb6a3cab2c7f87a78c16f7f3103496728edd6970',
#  '247c8747f6e85201e316195befbaef6cafc399a6085661a347e9bcd571a97204',
#  '09c4032f7e04108ae1349137c9958d58cc80765a58eac2cab3af93d605ce10c4',
#  'c14717dfad648242f635f0ced94465995adcdd328b19b14bc87092275770fe8d',
#  'a0fe834f2e67296946760f18c22e124560aa638358f736bf2549f047dcca522c',
#  'e8ba0e3e56c684664ac4b322bdf96a36c047b2b4595c1f8671a13c128a750373',
#  '00fd9fe11f45511d01af16c4e9ff635950e063f56dc6bdcbf7db4ea98d3957ad',
#  'c144b069a0b34f1088326bf7a21da71cd7ca31b439749a199992fe1600d2b841',
#  '1c3025b77033c1b989767b2a9ced67999f7bc66aa42b76506d768869e00af466',
#  '7a31e20637dfb16ce12fc69a06203fe52fd2a6832408f0f5a69b5e89a22cf721',
#  '6c744c0db0f7c9d6e0fae203b4c52dd373ba17102959c3031764a0efe1c38f8c',
#  '17132d12bad049dd348deb2d0d0a3b3d3ab7be96c05db569e72f32eed72dc597',
#  '776f8508f9b819a7312e6f15eea2048491c03ce4eb2f0c156b6f94423e1d6c28',
#  '7e45cf20671e785c43cc0d44eeb8d01c6ed409b9b79f531ee2dde1579d1f9043',
#  'ba9a1d33d5da524162ea61e89e4c3baaff91c0e1b72b6513454e83cc797762f2',
#  'fd7e2ef0a52397151c406babf4df2f3839279797c84633b18db2385f686e2969',
#  '38c921d564bdd64e68cddfe59eafd65024ba5cb4878dadbaf41e2cc95483e79b',
#  '7771d9f3678df0d84c2f7f0d32afdc96f7b272413852d040502dbd3e09128eab',
#  '6729daf1aafa2dfba56ffbee93d6e6fc7e5dd3eca9d972741eaa8f50810a901a',
#  'c6dbd1aba0f3f014ec78ca56342525f6aad34a6998cb1792e0fa33730ac5d547',
#  '3dc3bd08ef0d6040563ff860d715fb46819de59d68cec431f77e98da465bb2ad',
#  'd40a4d0978b85f345fc662a9c49c14740ecab6ee9b5cd01430abdfe6b4907a6b',
#  '1764baea5bd8140b14b257f67c2d60a802fc13e5b3f11bc0954b687d3e5ac851',
#  '483d09f534b77d7dc185b97993f7d22c3595f1e2217aa2e935b8f65eecff20ca',
# %%
event_table_name = "event_table"

# Deduplicate once for stable/efficient ANY() checks
deleted_node_hash_ids_list = sorted(set(deleted_node_hash_ids))

# Process in batches to reduce memory pressure
BATCH_SIZE = 10000
deleted_batches = [
    deleted_node_hash_ids_list[i : i + BATCH_SIZE]
    for i in range(0, len(deleted_node_hash_ids_list), BATCH_SIZE)
]

t0_event = time.perf_counter()
conn_event = psycopg2.connect(
    dbname=dbname,
    user=db_user,
    password=db_password,
    host=db_host,
    port=db_port,
    application_name="remove_events_with_deleted_nodes_main_only",
)

try:
    with conn_event:
        with conn_event.cursor() as cur_event:
            # Ensure main table exists
            cur_event.execute("SELECT to_regclass(%s)", (event_table_name,))
            has_event_main = cur_event.fetchone()[0] is not None
            if not has_event_main:
                raise RuntimeError(f"Table '{event_table_name}' does not exist.")

            # Count source rows
            cur_event.execute(
                sql.SQL("SELECT COUNT(*) FROM {}").format(sql.Identifier(event_table_name))
            )
            event_source_count = cur_event.fetchone()[0]

            # Count and delete rows in batches
            t_event_count = time.perf_counter()
            total_event_rows_to_delete = 0
            total_event_deleted_rows = 0

            for batch_idx, batch in enumerate(deleted_batches):
                try:
                    cur_event.execute(
                        sql.SQL(
                            """
                            SELECT COUNT(*)
                            FROM {}
                            WHERE (src_node IS NOT NULL AND src_node = ANY(%s))
                               OR (dst_node IS NOT NULL AND dst_node = ANY(%s))
                            """
                        ).format(sql.Identifier(event_table_name)),
                        (batch, batch),
                    )
                    batch_rows_to_delete = cur_event.fetchone()[0]
                    total_event_rows_to_delete += batch_rows_to_delete

                    cur_event.execute(
                        sql.SQL(
                            """
                            DELETE FROM {}
                            WHERE (src_node IS NOT NULL AND src_node = ANY(%s))
                               OR (dst_node IS NOT NULL AND dst_node = ANY(%s))
                            """
                        ).format(sql.Identifier(event_table_name)),
                        (batch, batch),
                    )
                    total_event_deleted_rows += cur_event.rowcount
                    conn_event.commit()

                    print(
                        f"Batch {batch_idx + 1}/{len(deleted_batches)}: "
                        f"Deleted {cur_event.rowcount} rows "
                        f"(counted {batch_rows_to_delete} to delete) "
                        f"in {time.perf_counter() - t_event_count:.3f}s"
                    )

                except psycopg2.errors.DiskFull as e:
                    print(f"Disk full error in batch {batch_idx}. Stopping gracefully.")
                    conn_event.rollback()
                    raise

            print(
                f"Rows to delete from '{event_table_name}': {total_event_rows_to_delete} "
                f"(counted in {time.perf_counter() - t_event_count:.3f}s)"
            )
            print(f"Deleted {total_event_deleted_rows} rows from '{event_table_name}'")
            print(f"Event source rows: {event_source_count}")
            print(f"Event remaining rows: {event_source_count - total_event_deleted_rows}")

finally:
    conn_event.close()

print(f"Total event-table elapsed: {time.perf_counter() - t0_event:.3f}s")
# Out:
# Batch 1/3: Deleted 15 rows (counted 15 to delete) in 125.337s
# Batch 2/3: Deleted 190 rows (counted 190 to delete) in 198.827s
# Batch 3/3: Deleted 8 rows (counted 8 to delete) in 272.810s
# Rows to delete from 'event_table': 213 (counted in 272.810s)
# Deleted 213 rows from 'event_table'
# Event source rows: 140994662
# Event remaining rows: 140994449
# Total event-table elapsed: 314.602s
