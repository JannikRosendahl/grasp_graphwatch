# %%
import os
from pathlib import Path

nb_dir = Path.cwd()
        

target = (nb_dir / '..' / '..').resolve()
os.chdir(target)

# %%
from grasp.graph.graph_storage import GraphStorage, load_graph_storage

gs_path = "data/theia_e3/graph_storage/theia_e3_default_experiment_dataset-theia_e3_context_size-120_step_size-120_graph_storage.pt"
gs: GraphStorage = load_graph_storage(gs_path)


print(gs)
known_executables = gs.train_subject_cmds
print(len(known_executables))
print(len(known_executables))
# Out:
# <grasp.graph.graph_storage.GraphStorage object at 0x7bd161255460>
# 108293
# 108293

# %%
gs.train_subject_cmds
# Out:
# ['/sbin/init',
#  '/bin/dbus-daemon',
#  '/usr/bin/python2.7',
#  '/usr/sbin/cupsd',
#  '/usr/lib/telepathy/mission-control-5',
#  '/usr/lib/ubuntu-geoip/ubuntu-geoip-provider',
#  '/usr/bin/nm-applet',
#  '/usr/lib/x86_64-linux-gnu/colord/colord',
#  '/usr/bin/bluetooth-applet',
#  '/usr/lib/udisks/udisks-daemon',
#  '/usr/sbin/NetworkManager',
#  '/usr/lib/upower/upowerd',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/lib/accountsservice/accounts-daemon',
#  '/usr/lib/policykit-1/polkitd',
#  '/usr/lib/policykit-1/polkitd',
#  '/usr/sbin/modem-manager',
#  '/usr/lib/indicator-session/indicator-session-service',
#  '/usr/lib/indicator-session/indicator-session-service',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/bin/fluxbox',
#  '/usr/bin/Xvnc4',
#  '/usr/bin/update-notifier',
#  '/usr/bin/update-notifier',
#  '/bin/dash',
#  '/usr/bin/update-notifier',
#  '/usr/bin/update-notifier',
#  '/usr/bin/metacity',
#  '/usr/lib/gnome-settings-daemon/gnome-settings-daemon',
#  '/usr/sbin/sshd',
#  '/usr/sbin/sshd',
#  '/usr/sbin/sshd',
#  '/bin/bash',
#  '/usr/lib/bamf/bamfdaemon',
#  '/usr/bin/nautilus',
#  '/usr/bin/unity-2d-shell',
#  '/usr/bin/unity-2d-panel',
#  '/usr/lib/bamf/bamfdaemon',
#  '/bin/dbus-daemon',
#  '/usr/lib/indicator-appmenu/hud-service',
#  '/usr/lib/unity/unity-panel-service',
#  '/usr/lib/unity/unity-panel-service',
#  '/usr/bin/unity-2d-panel',
#  '/sbin/mountall',
#  '/usr/bin/whoopsie',
#  '/bin/bash',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/sbin/ntpd',
#  '/bin/bash',
#  '/bin/bash',
#  '/usr/bin/sudo',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/ubuntu-geoip/ubuntu-geoip-provider',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/bin/bash',
#  '/bin/bash',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/bin/bash',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/bin/pulseaudio',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/lib/indicator-datetime/indicator-datetime-service',
#  '/usr/lib/policykit-1-gnome/polkit-gnome-authentication-agent-1',
#  '/usr/lib/udisks/udisks-daemon',
#  '/usr/sbin/NetworkManager',
#  '/usr/lib/upower/upowerd',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/lib/accountsservice/accounts-daemon',
#  '/usr/bin/zeitgeist-daemon',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/ubuntu-geoip/ubuntu-geoip-provider',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/ubuntu-geoip/ubuntu-geoip-provider',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/bin/gnome-screensaver',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/indicator-printers/indicator-printers-service',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/fluxbox',
#  '/bin/dash',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/bin/dbus-launch',
#  '/usr/bin/dbus-launch',
#  '/usr/bin/dbus-launch',
#  '/bin/dbus-daemon',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/bin/dbus-daemon',
#  '/bin/dbus-daemon',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/pulseaudio',
#  '/usr/lib/rtkit/rtkit-daemon',
#  '/usr/bin/pulseaudio',
#  '/usr/lib/pulseaudio/pulse/gconf-helper',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/pulseaudio',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/sbin/cron',
#  '/usr/sbin/cron',
#  '/usr/sbin/cron',
#  '/bin/run-parts',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/ubuntu-geoip/ubuntu-geoip-provider',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/sbin/dhclient',
#  '/usr/bin/python2.7',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/fluxbox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/bin/fluxbox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/bin/fluxbox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/sbin/dhclient',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/fluxbox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/bin/python2.7',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/sbin/sshd',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/console-kit-daemon',
#  '/bin/dash',
#  '/usr/bin/env',
#  '/bin/dash',
#  '/bin/uname',
#  '/bin/uname',
#  '/bin/uname',
#  '/bin/dash',
#  '/bin/grep',
#  '/bin/uname',
#  '/bin/dash',
#  '/usr/bin/stat',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/python2.7',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/stat',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/stat',
#  '/bin/cat',
#  '/bin/dash',
#  '/bin/cat',
#  '/bin/dash',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-config',
#  '/usr/bin/find',
#  '/bin/cat',
#  '/bin/dash',
#  '/usr/bin/stat',
#  '/bin/date',
#  '/usr/bin/gawk',
#  '/bin/mount',
#  '/bin/dash',
#  '/usr/bin/cut',
#  '/bin/grep',
#  '/usr/bin/cut',
#  '/bin/grep',
#  '/usr/bin/cut',
#  '/usr/bin/cut',
#  '/bin/grep',
#  '/usr/bin/cut',
#  '/bin/grep',
#  '/bin/date',
#  '/bin/cat',
#  '/bin/dash',
#  '/bin/dash',
#  '/usr/sbin/sshd',
#  '/usr/sbin/sshd',
#  '/usr/bin/groups',
#  '/bin/uname',
#  '/bin/sed',
#  '/bin/ls',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/usr/bin/sort',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/dash',
#  '/usr/bin/basename',
#  '/usr/bin/dirname',
#  '/usr/bin/dircolors',
#  '/bin/uname',
#  '/bin/sed',
#  '/bin/ls',
#  '/bin/bash',
#  '/bin/bash',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/bin/sed',
#  '/usr/bin/sort',
#  '/bin/sed',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/bin/bash',
#  '/bin/bash',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/fluxbox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/lib/ubuntu-geoip/ubuntu-geoip-provider',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/bin/fluxbox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/bin/python2.7',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/bin/python2.7',
#  '/usr/bin/fluxbox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/pulseaudio',
#  '/usr/lib/pulseaudio/pulse/gconf-helper',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/pulseaudio',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/bin/python2.7',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/usr/bin/fluxbox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  '/home/admin/Downloads/firefox/firefox',
#  ...]

# %%
gs.train_subject_cmd_to_id
# Out:
# {'/bin/bash': 0,
#  '/bin/cat': 1,
#  '/bin/dash': 2,
#  '/bin/date': 3,
#  '/bin/dbus-daemon': 4,
#  '/bin/egrep': 5,
#  '/bin/fusermount': 6,
#  '/bin/grep': 7,
#  '/bin/gzip': 8,
#  '/bin/ls': 9,
#  '/bin/lsmod': 10,
#  '/bin/mount': 11,
#  '/bin/mv': 12,
#  '/bin/rm': 13,
#  '/bin/run-parts': 14,
#  '/bin/sed': 15,
#  '/bin/sleep': 16,
#  '/bin/su': 17,
#  '/bin/touch': 18,
#  '/bin/uname': 19,
#  '/home/admin/Downloads/firefox/firefox': 20,
#  '/sbin/acpi_available': 21,
#  '/sbin/dhclient': 22,
#  '/sbin/init': 23,
#  '/sbin/initctl': 24,
#  '/sbin/mountall': 25,
#  '/sbin/runlevel': 26,
#  '/sbin/start-stop-daemon': 27,
#  '/sbin/udevd': 28,
#  '/sbin/upstart-socket-bridge': 29,
#  '/sbin/upstart-udev-bridge': 30,
#  '/usr/bin/Xorg': 31,
#  '/usr/bin/Xvnc4': 32,
#  '/usr/bin/apt-config': 33,
#  '/usr/bin/apt-get': 34,
#  '/usr/bin/basename': 35,
#  '/usr/bin/bluetooth-applet': 36,
#  '/usr/bin/cmp': 37,
#  '/usr/bin/cut': 38,
#  '/usr/bin/dbus-launch': 39,
#  '/usr/bin/dircolors': 40,
#  '/usr/bin/dirname': 41,
#  '/usr/bin/dpkg': 42,
#  '/usr/bin/dpkg-statoverride': 43,
#  '/usr/bin/du': 44,
#  '/usr/bin/env': 45,
#  '/usr/bin/find': 46,
#  '/usr/bin/flock': 47,
#  '/usr/bin/fluxbox': 48,
#  '/usr/bin/gawk': 49,
#  '/usr/bin/getent': 50,
#  '/usr/bin/gnome-control-center': 51,
#  '/usr/bin/gnome-keyring-daemon': 52,
#  '/usr/bin/gnome-screensaver': 53,
#  '/usr/bin/gnome-session': 54,
#  '/usr/bin/gnome-terminal': 55,
#  '/usr/bin/groups': 56,
#  '/usr/bin/head': 57,
#  '/usr/bin/ionice': 58,
#  '/usr/bin/metacity': 59,
#  '/usr/bin/nautilus': 60,
#  '/usr/bin/nice': 61,
#  '/usr/bin/nm-applet': 62,
#  '/usr/bin/perl': 63,
#  '/usr/bin/pgrep': 64,
#  '/usr/bin/pulseaudio': 65,
#  '/usr/bin/python2.7': 66,
#  '/usr/bin/sort': 67,
#  '/usr/bin/stat': 68,
#  '/usr/bin/sudo': 69,
#  '/usr/bin/telepathy-indicator': 70,
#  '/usr/bin/tr': 71,
#  '/usr/bin/unity-2d-panel': 72,
#  '/usr/bin/unity-2d-shell': 73,
#  '/usr/bin/unity-2d-spread': 74,
#  '/usr/bin/update-notifier': 75,
#  '/usr/bin/whoopsie': 76,
#  '/usr/bin/xargs': 77,
#  '/usr/bin/xterm': 78,
#  '/usr/bin/zeitgeist-daemon': 79,
#  '/usr/bin/zeitgeist-datahub': 80,
#  '/usr/lib/accountsservice/accounts-daemon': 81,
#  '/usr/lib/bamf/bamfdaemon': 82,
#  '/usr/lib/geoclue/geoclue-master': 83,
#  '/usr/lib/gnome-disk-utility/gdu-notification-daemon': 84,
#  '/usr/lib/gnome-settings-daemon/gnome-fallback-mount-helper': 85,
#  '/usr/lib/gnome-settings-daemon/gnome-settings-daemon': 86,
#  '/usr/lib/gvfs/gvfs-afc-volume-monitor': 87,
#  '/usr/lib/gvfs/gvfs-fuse-daemon': 88,
#  '/usr/lib/gvfs/gvfs-gdu-volume-monitor': 89,
#  '/usr/lib/gvfs/gvfs-gphoto2-volume-monitor': 90,
#  '/usr/lib/gvfs/gvfsd': 91,
#  '/usr/lib/indicator-application/indicator-application-service': 92,
#  '/usr/lib/indicator-appmenu/hud-service': 93,
#  '/usr/lib/indicator-datetime/indicator-datetime-service': 94,
#  '/usr/lib/indicator-messages/indicator-messages-service': 95,
#  '/usr/lib/indicator-printers/indicator-printers-service': 96,
#  '/usr/lib/indicator-session/gtk-logout-helper': 97,
#  '/usr/lib/indicator-session/indicator-session-service': 98,
#  '/usr/lib/indicator-sound/indicator-sound-service': 99,
#  '/usr/lib/notify-osd/notify-osd': 100,
#  '/usr/lib/policykit-1-gnome/polkit-gnome-authentication-agent-1': 101,
#  '/usr/lib/policykit-1/polkitd': 102,
#  '/usr/lib/postgresql/9.1/bin/postgres': 103,
#  '/usr/lib/pulseaudio/pulse/gconf-helper': 104,
#  '/usr/lib/rtkit/rtkit-daemon': 105,
#  '/usr/lib/telepathy/mission-control-5': 106,
#  '/usr/lib/thunderbird/crashreporter': 107,
#  '/usr/lib/thunderbird/thunderbird': 108,
#  '/usr/lib/ubuntu-geoip/ubuntu-geoip-provider': 109,
#  '/usr/lib/udisks/udisks-daemon': 110,
#  '/usr/lib/unity-lens-applications/unity-applications-daemon': 111,
#  '/usr/lib/unity-lens-files/unity-files-daemon': 112,
#  '/usr/lib/unity-lens-music/unity-music-daemon': 113,
#  '/usr/lib/unity-lens-music/unity-musicstore-daemon': 114,
#  '/usr/lib/unity/unity-panel-service': 115,
#  '/usr/lib/upower/upowerd': 116,
#  '/usr/lib/x86_64-linux-gnu/colord/colord': 117,
#  '/usr/lib/x86_64-linux-gnu/gconf/gconfd-2': 118,
#  '/usr/lib/zeitgeist/zeitgeist-fts': 119,
#  '/usr/sbin/NetworkManager': 120,
#  '/usr/sbin/acpid': 121,
#  '/usr/sbin/anacron': 122,
#  '/usr/sbin/console-kit-daemon': 123,
#  '/usr/sbin/cron': 124,
#  '/usr/sbin/cupsd': 125,
#  '/usr/sbin/logrotate': 126,
#  '/usr/sbin/modem-manager': 127,
#  '/usr/sbin/ntpd': 128,
#  '/usr/sbin/sshd': 129}

# %%
len(set(known_executables))
# Out:
# 130

# %%
known_executables_set = set(known_executables)
known_executables_list = sorted(known_executables_set)
print(len(known_executables_list))
known_executables_list
# Out:
# 130
# ['/bin/bash',
#  '/bin/cat',
#  '/bin/dash',
#  '/bin/date',
#  '/bin/dbus-daemon',
#  '/bin/egrep',
#  '/bin/fusermount',
#  '/bin/grep',
#  '/bin/gzip',
#  '/bin/ls',
#  '/bin/lsmod',
#  '/bin/mount',
#  '/bin/mv',
#  '/bin/rm',
#  '/bin/run-parts',
#  '/bin/sed',
#  '/bin/sleep',
#  '/bin/su',
#  '/bin/touch',
#  '/bin/uname',
#  '/home/admin/Downloads/firefox/firefox',
#  '/sbin/acpi_available',
#  '/sbin/dhclient',
#  '/sbin/init',
#  '/sbin/initctl',
#  '/sbin/mountall',
#  '/sbin/runlevel',
#  '/sbin/start-stop-daemon',
#  '/sbin/udevd',
#  '/sbin/upstart-socket-bridge',
#  '/sbin/upstart-udev-bridge',
#  '/usr/bin/Xorg',
#  '/usr/bin/Xvnc4',
#  '/usr/bin/apt-config',
#  '/usr/bin/apt-get',
#  '/usr/bin/basename',
#  '/usr/bin/bluetooth-applet',
#  '/usr/bin/cmp',
#  '/usr/bin/cut',
#  '/usr/bin/dbus-launch',
#  '/usr/bin/dircolors',
#  '/usr/bin/dirname',
#  '/usr/bin/dpkg',
#  '/usr/bin/dpkg-statoverride',
#  '/usr/bin/du',
#  '/usr/bin/env',
#  '/usr/bin/find',
#  '/usr/bin/flock',
#  '/usr/bin/fluxbox',
#  '/usr/bin/gawk',
#  '/usr/bin/getent',
#  '/usr/bin/gnome-control-center',
#  '/usr/bin/gnome-keyring-daemon',
#  '/usr/bin/gnome-screensaver',
#  '/usr/bin/gnome-session',
#  '/usr/bin/gnome-terminal',
#  '/usr/bin/groups',
#  '/usr/bin/head',
#  '/usr/bin/ionice',
#  '/usr/bin/metacity',
#  '/usr/bin/nautilus',
#  '/usr/bin/nice',
#  '/usr/bin/nm-applet',
#  '/usr/bin/perl',
#  '/usr/bin/pgrep',
#  '/usr/bin/pulseaudio',
#  '/usr/bin/python2.7',
#  '/usr/bin/sort',
#  '/usr/bin/stat',
#  '/usr/bin/sudo',
#  '/usr/bin/telepathy-indicator',
#  '/usr/bin/tr',
#  '/usr/bin/unity-2d-panel',
#  '/usr/bin/unity-2d-shell',
#  '/usr/bin/unity-2d-spread',
#  '/usr/bin/update-notifier',
#  '/usr/bin/whoopsie',
#  '/usr/bin/xargs',
#  '/usr/bin/xterm',
#  '/usr/bin/zeitgeist-daemon',
#  '/usr/bin/zeitgeist-datahub',
#  '/usr/lib/accountsservice/accounts-daemon',
#  '/usr/lib/bamf/bamfdaemon',
#  '/usr/lib/geoclue/geoclue-master',
#  '/usr/lib/gnome-disk-utility/gdu-notification-daemon',
#  '/usr/lib/gnome-settings-daemon/gnome-fallback-mount-helper',
#  '/usr/lib/gnome-settings-daemon/gnome-settings-daemon',
#  '/usr/lib/gvfs/gvfs-afc-volume-monitor',
#  '/usr/lib/gvfs/gvfs-fuse-daemon',
#  '/usr/lib/gvfs/gvfs-gdu-volume-monitor',
#  '/usr/lib/gvfs/gvfs-gphoto2-volume-monitor',
#  '/usr/lib/gvfs/gvfsd',
#  '/usr/lib/indicator-application/indicator-application-service',
#  '/usr/lib/indicator-appmenu/hud-service',
#  '/usr/lib/indicator-datetime/indicator-datetime-service',
#  '/usr/lib/indicator-messages/indicator-messages-service',
#  '/usr/lib/indicator-printers/indicator-printers-service',
#  '/usr/lib/indicator-session/gtk-logout-helper',
#  '/usr/lib/indicator-session/indicator-session-service',
#  '/usr/lib/indicator-sound/indicator-sound-service',
#  '/usr/lib/notify-osd/notify-osd',
#  '/usr/lib/policykit-1-gnome/polkit-gnome-authentication-agent-1',
#  '/usr/lib/policykit-1/polkitd',
#  '/usr/lib/postgresql/9.1/bin/postgres',
#  '/usr/lib/pulseaudio/pulse/gconf-helper',
#  '/usr/lib/rtkit/rtkit-daemon',
#  '/usr/lib/telepathy/mission-control-5',
#  '/usr/lib/thunderbird/crashreporter',
#  '/usr/lib/thunderbird/thunderbird',
#  '/usr/lib/ubuntu-geoip/ubuntu-geoip-provider',
#  '/usr/lib/udisks/udisks-daemon',
#  '/usr/lib/unity-lens-applications/unity-applications-daemon',
#  '/usr/lib/unity-lens-files/unity-files-daemon',
#  '/usr/lib/unity-lens-music/unity-music-daemon',
#  '/usr/lib/unity-lens-music/unity-musicstore-daemon',
#  '/usr/lib/unity/unity-panel-service',
#  '/usr/lib/upower/upowerd',
#  '/usr/lib/x86_64-linux-gnu/colord/colord',
#  '/usr/lib/x86_64-linux-gnu/gconf/gconfd-2',
#  '/usr/lib/zeitgeist/zeitgeist-fts',
#  '/usr/sbin/NetworkManager',
#  '/usr/sbin/acpid',
#  '/usr/sbin/anacron',
#  '/usr/sbin/console-kit-daemon',
#  '/usr/sbin/cron',
#  '/usr/sbin/cupsd',
#  '/usr/sbin/logrotate',
#  '/usr/sbin/modem-manager',
#  '/usr/sbin/ntpd',
#  '/usr/sbin/sshd']

# %%
import time
from urllib.parse import unquote, urlparse

import psycopg2  # type: ignore
from psycopg2 import sql  # type: ignore

from grasp import config
from grasp.schema import DatasetName

user = "postgres"
password = "lolroflomg"
host = config.DB_HOST
port = 9889

base_url = f"postgresql://{user}:{password}@{host}:{port}"
connection_real_data = f"{base_url}/{DatasetName.THEIA_E3.value}"

# Known executable commands from training graph storage
known_executables_set = set(known_executables)
known_executables_list = sorted(known_executables_set)

new_table_name = "subject_node_table"
backup_table_name = f"{new_table_name}_backup"

# Parse connection URL once
parsed = urlparse(connection_real_data)
dbname = parsed.path.lstrip('/') if parsed.path else None
db_user = unquote(parsed.username) if parsed.username else None
db_password = unquote(parsed.password) if parsed.password else None
db_host = parsed.hostname
db_port = parsed.port

t0 = time.perf_counter()
conn = psycopg2.connect(
    dbname=dbname,
    user=db_user,
    password=db_password,
    host=db_host,
    port=db_port,
    application_name="remove_process_unknown_exec_fast",
)

try:
    with conn, conn.cursor() as cur:
        # Fast path: keep one immutable backup, recreate filtered table from it.
        # If backup already exists, reuse it. If not, rename original once.
        cur.execute("SELECT to_regclass(%s)", (new_table_name,))
        has_main = cur.fetchone()[0] is not None # type: ignore
        cur.execute("SELECT to_regclass(%s)", (backup_table_name,))
        has_backup = cur.fetchone()[0] is not None # type: ignore

        if not has_main and not has_backup:
            raise RuntimeError(
                f"Neither '{new_table_name}' nor '{backup_table_name}' exists."
            )

        if has_main and not has_backup:
            t_rename = time.perf_counter()
            cur.execute(
                sql.SQL("ALTER TABLE {} RENAME TO {}").format(
                    sql.Identifier(new_table_name),
                    sql.Identifier(backup_table_name),
                )
            )
            print(
                f"Renamed original table to backup in "
                f"{time.perf_counter() - t_rename:.3f}s"
            )
        elif has_main and has_backup:
            # Keep existing backup as source of truth; refresh working table below.
            print(
                f"Both '{new_table_name}' and '{backup_table_name}' exist; "
                "keeping backup and refreshing working table."
            )

        source_table = backup_table_name if has_backup or has_main else new_table_name

        # Remember node_uuids that will be removed (unknown execs + NULL cmd)
        t_collect = time.perf_counter()
        cur.execute(
            sql.SQL(
                """
                    SELECT hash_id
                    FROM {}
                    WHERE path IS NULL OR NOT (path = ANY(%s))
                    """
            ).format(sql.Identifier(source_table)),
            (known_executables_list,),
        )
        deleted_node_hash_ids = [row[0] for row in cur.fetchall()]
        print(
            f"Collected {len(deleted_node_hash_ids)} deleted node_hash_ids in "
            f"{time.perf_counter() - t_collect:.3f}s"
        )

        t_rebuild = time.perf_counter()
        cur.execute(
            sql.SQL("DROP TABLE IF EXISTS {}").format(
                sql.Identifier(new_table_name)
            )
        )
        cur.execute(
            sql.SQL("CREATE TABLE {} (LIKE {} INCLUDING ALL)").format(
                sql.Identifier(new_table_name),
                sql.Identifier(source_table),
            )
        )
        cur.execute(
            sql.SQL(
                "INSERT INTO {} SELECT * FROM {} WHERE path = ANY(%s)"
            ).format(
                sql.Identifier(new_table_name),
                sql.Identifier(source_table),
            ),
            (known_executables_list,),
        )

        inserted_rows = cur.rowcount
        print(
            f"Rebuilt filtered '{new_table_name}' with {inserted_rows} rows in "
            f"{time.perf_counter() - t_rebuild:.3f}s"
        )

        # Useful sanity numbers
        cur.execute(
            sql.SQL("SELECT COUNT(*) FROM {}").format(
                sql.Identifier(source_table) 
            )
        )
        source_count = cur.fetchone()[0] # type: ignore
        print(f"Source rows: {source_count}")
        print(f"Deleted rows: {source_count - inserted_rows}")

finally:
    conn.close()

print(f"Total elapsed: {time.perf_counter() - t0:.3f}s")
# Out:
# Renamed original table to backup in 0.000s
# Collected 6712 deleted node_hash_ids in 0.280s
# Rebuilt filtered 'subject_node_table' with 271651 rows in 1.748s
# Source rows: 278363
# Deleted rows: 6712
# Total elapsed: 2.085s

# %%
deleted_node_hash_ids
# Out:
# ['f066a4845c97b11363419f6598d052e879dfccc22785d9b73553c015e6816b07',
#  'be87ba292daae8688b312b858da1a484439f40664fd37ae66b91bbc5d7ca6957',
#  '1b784f37f3f7f6a4ae8df60570b0f61a7b4ac7c88ce6ba2ee95f30a896361705',
#  '797ced1f7cde9752d018a02aea9f62e54d008f387e43325fdef91d787aea8b68',
#  'bf32ed72f6e16e975f20a51dbff6906a1deae49068e7c9eae666ecb8b0b58fd4',
#  '67e231294104efc214fb2fc7b169830d5653d18ec955ef57e29cf8bac11f4dc4',
#  '7f559004b83079671a8d2b9e99e38413ac0ad62bff4acea6b92f17911f84d01f',
#  '0cf97c5bad6c513b0db52c24764b1150e4537b967f8922d6ed2ea20cb4561a42',
#  'fc3eb3c5fc782e1311b1450f595edae480c2581ff59145dc059b84be62dd5860',
#  'b6800f98974c4c97092975e2b852815d704709debc84d420e1ac0a7bf3cd310a',
#  '3858fb14cb26ec3f9808781ea5c75ff92f4be81c40b2a439c0b7628963b9c8a7',
#  '1327fb5aaeca9fee6fe15404c50d5e92d33121afc32e925c143302876b9c1952',
#  '725eda17507dec785f78477721e9144d7e01c29abff41526235db81b48a9197c',
#  '7f7c3ac38295c3a9469dbae1e5a729a33f8646df2eb6d3e4bad3ff948b9a6aaf',
#  'f647ec66b35111f90c67f2febecf57e902376a516497564595c144e1bce170bd',
#  'fc298b2227d6fe7a93a3c422af221e769182e1531b88bbdc7d800d705394bf02',
#  'd742f8465a9ee7daacb5d6615d1742cfbf623a4ccbaddf9012f99c1d4a55e31f',
#  ...]

# %%
event_table_name = "event_table"

# Deduplicate once for stable/efficient ANY() checks
deleted_node_hash_ids_list = sorted(set(deleted_node_hash_ids))

# Process in batches to reduce memory pressure
BATCH_SIZE = 10000
deleted_batches = [
    deleted_node_hash_ids_list[i : i + BATCH_SIZE]
    for i in range(0, len(deleted_node_hash_ids_list), BATCH_SIZE)
]

t0_event = time.perf_counter()
conn_event = psycopg2.connect(
    dbname=dbname,
    user=db_user,
    password=db_password,
    host=db_host,
    port=db_port,
    application_name="remove_events_with_deleted_nodes_main_only",
)

try:
    with conn_event, conn_event.cursor() as cur_event:
        # Ensure main table exists
        cur_event.execute("SELECT to_regclass(%s)", (event_table_name,))
        has_event_main = cur_event.fetchone()[0] is not None # type: ignore
        if not has_event_main:
            raise RuntimeError(f"Table '{event_table_name}' does not exist.")

        # Count source rows
        cur_event.execute(
            sql.SQL("SELECT COUNT(*) FROM {}").format(sql.Identifier(event_table_name))
        )
        event_source_count = cur_event.fetchone()[0] # type: ignore

        # Count and delete rows in batches
        t_event_count = time.perf_counter()
        total_event_rows_to_delete = 0
        total_event_deleted_rows = 0

        for batch_idx, batch in enumerate(deleted_batches):
            try:
                cur_event.execute(
                    sql.SQL(
                        """
                            SELECT COUNT(*)
                            FROM {}
                            WHERE (src_node IS NOT NULL AND src_node = ANY(%s))
                               OR (dst_node IS NOT NULL AND dst_node = ANY(%s))
                            """
                    ).format(sql.Identifier(event_table_name)),
                    (batch, batch),
                )
                batch_rows_to_delete = cur_event.fetchone()[0] # type: ignore
                total_event_rows_to_delete += batch_rows_to_delete

                cur_event.execute(
                    sql.SQL(
                        """
                            DELETE FROM {}
                            WHERE (src_node IS NOT NULL AND src_node = ANY(%s))
                               OR (dst_node IS NOT NULL AND dst_node = ANY(%s))
                            """
                    ).format(sql.Identifier(event_table_name)),
                    (batch, batch),
                )
                total_event_deleted_rows += cur_event.rowcount
                conn_event.commit()

                print(
                    f"Batch {batch_idx + 1}/{len(deleted_batches)}: "
                    f"Deleted {cur_event.rowcount} rows "
                    f"(counted {batch_rows_to_delete} to delete) "
                    f"in {time.perf_counter() - t_event_count:.3f}s"
                )

            except psycopg2.errors.DiskFull:
                print(f"Disk full error in batch {batch_idx}. Stopping gracefully.")
                conn_event.rollback()
                raise

        print(
            f"Rows to delete from '{event_table_name}': {total_event_rows_to_delete} "
            f"(counted in {time.perf_counter() - t_event_count:.3f}s)"
        )
        print(f"Deleted {total_event_deleted_rows} rows from '{event_table_name}'")
        print(f"Event source rows: {event_source_count}")
        print(f"Event remaining rows: {event_source_count - total_event_deleted_rows}")

finally:
    conn_event.close()

print(f"Total event-table elapsed: {time.perf_counter() - t0_event:.3f}s")
# Out:
# Batch 1/1: Deleted 691931 rows (counted 691931 to delete) in 13.857s
# Rows to delete from 'event_table': 691931 (counted in 13.857s)
# Deleted 691931 rows from 'event_table'
# Event source rows: 44366117
# Event remaining rows: 43674186
# Total event-table elapsed: 27.894s
